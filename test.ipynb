# %%
from orthoagent.agents.agent import simple_agent

simple_agent.chat("What is the minimum stem diameter?")
# Out:
# Parsing files: 100%|██████████| 1/1 [00:24<00:00, 24.11s/it]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 1it [00:00, 39945.75it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 1it [00:00, 22795.13it/s]
# 1it [00:00, 15363.75it/s]
# 0it [00:00, ?it/s]
# 1it [00:00, 20460.02it/s]
# 1it [00:00, 17260.51it/s]
# 0it [00:00, ?it/s]
# 1it [00:00, 17549.39it/s]
# 2it [00:00, 28926.23it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 1it [00:00, 23172.95it/s]
# 1it [00:00, 15768.06it/s]
# 1it [00:00, 16912.52it/s]
# 0it [00:00, ?it/s]
# 1it [00:00, 18558.87it/s]
# 1it [00:00, 20460.02it/s]
# 1it [00:00, 15650.39it/s]
# 1it [00:00, 16131.94it/s]
# 2it [00:00, 29330.80it/s]
# 1it [00:00, 20068.44it/s]
# 1it [00:00, 20360.70it/s]
# 1it [00:00, 15887.52it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 1it [00:00, 21732.15it/s]
# 1it [00:00, 19691.57it/s]
# ...

# %%
simple_agent
