# %%
from orthoagent.agents.agent import simple_agent


simple_agent.chat("“How long is the distal femoral component?” Give me the answer for 1.) depuy 2.) onko 3.)zimmer 4.) stryker")
# Out:
# Loading files: 100%|██████████| 4/4 [00:03<00:00,  1.11file/s]
# /Users/andrewyang/anaconda3/lib/python3.11/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# Started parsing the file under job_id 18db4175-dded-4972-bc35-6644d0abcaf1
# .Started parsing the file under job_id b17ea27a-6551-454f-a1f6-f6e6b58c9530
# .Started parsing the file under job_id f9a2652a-38ac-4d60-b77f-610833a67535
# Started parsing the file under job_id 619c3dcc-6122-45db-9acc-30a6f9d85a95
# .Added user message to memory: “How long is the distal femoral component?” Give me the answer for 1.) depuy 2.) onko 3.)zimmer 4.) stryker
# === Calling Function ===
# Calling function: query_engine with args: {"input": "distal femoral component length site:depuy.com"}
# Got output: The distal femoral component length information can be found on the site depuy.com.
# ========================
#
# === Calling Function ===
# Calling function: query_engine with args: {"input": "distal femoral component length site:onko.com"}
# Got output: The distal femoral component length information can be found on the Onkos Surgical website.
# ========================
#
# === Calling Function ===
# Calling function: query_engine with args: {"input": "distal femoral component length site:zimmer.com"}
# Got output: The distal femoral component length information can be found on the Zimmer website.
# ========================
#
# === Calling Function ===
# Calling function: query_engine with args: {"input": "distal femoral component length site:stryker.com"}
# Got output: The distal femoral component length information can be found on the Stryker website.
# ========================
# AgentChatResponse(response='I do not have enough information to answer the question about the length of the distal femoral component for Depuy, Onko, Zimmer, and Stryker. However, you can find this information on their respective websites:\n\n1. Depuy: [depuy.com](https://www.depuy.com)\n2. Onko: [onkosurgical.com](https://www.onkosurgical.com)\n3. Zimmer: [zimmer.com](https://www.zimmer.com)\n4. Stryker: [stryker.com](https://www.stryker.com)', sources=[ToolOutput(content='The distal femoral component length information can be found on the site depuy.com.', tool_name='query_engine', raw_input={'input': 'distal femoral component length site:depuy.com'}, raw_output=Response(response='The distal femoral component length information can be found on the site depuy.com.', source_nodes=[NodeWithScore(node=TextNode(id_='16c4d27f-4a85-4c8e-9bc1-ab30a5b10386', embedding=None, metadata={'page_label': '47', 'file_name': '003 GMRS Distal Femoral Surgical Protocol.pdf', 'file_path': '/Users/andrewyang/Desktop/research/AgenticRAG/orthoagent/reference_docs/003 GMRS Distal Femoral Surgical Protocol.pdf', 'file_type': 'application/pdf', 'file_size': 1391705, 'creation_date': '2024-09-22', 'last_modified_date': '2024-09-22'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5d16e255-acfd-4f07-b458-ea0f47acafbb', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '47', 'file_name': '003 GMRS Distal Femoral Surgical Protocol.pdf', 'file_path': '/Users/andrewyang/Desktop/research/AgenticRAG/orthoagent/reference_docs/003 GMRS Distal Femoral Surgical Protocol.pdf', 'file_type': 'application/pdf', 'file_size': 1391705, 'creation_date': '2024-09-22', 'last_modified_date': '2024-09-22'}, hash='1e457f1d4e22b9d4314a90f224ac32d08b6c4537cb5a420a4d2dfb7ce8b09fef')}, text='47Distal Femoral Component Length 65mm\nStem Without Body 11mm\nStem With Body 40mm\n Extension Stem Without Stem With\n Piece Length Body Body\nNone 76mm 105mm\n30mm 106mm 135mm\n40mm 116mm 145mm\n50mm 126mm 155mm\n60mm 136mm 165mm\n70mm 146mm 175mm\n80mm 156mm 185mm\n90mm (40 + 50) 166mm 195mm\n100mm 176mm 205mm\n110mm (50 + 60) 186mm 215mm\n120mm 196mm 225mm\n130mm (50 + 80) 206mm 235mm\n140mm 216mm 245mm\n150mm (50 + 100) 226mm 255mm\n160mm 236mm 265mm\n170mm (50 + 120) 246mm 275mm\n180mm 256mm 285mm\n190mm (50 + 140) 266mm 295mm\n200mm 276mm 305mm\n210mm (50 + 160) 286mm 315mm\n220mm 296mm 325mmDistal Femur Resection Length Overview Chart', mimetype='text/plain', start_char_idx=0, end_char_idx=626, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.845054955372372), NodeWithScore(node=TextNode(id_='a171c41b-10a7-43db-a283-1cd62f0d4d5d', embedding=None, metadata={'page_label': '19', 'file_name': '003 GMRS Distal Femoral Surgical Protocol.pdf', 'file_path': '/Users/andrewyang/Desktop/research/AgenticRAG/orthoagent/reference_docs/003 GMRS Distal Femoral Surgical Protocol.pdf', 'file_type': 'application/pdf', 'file_size': 1391705, 'creation_date': '2024-09-22', 'last_modified_date': '2024-09-22'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='085a3dd2-04c2-490c-9ff0-a2705fda328d', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '19', 'file_name': '003 GMRS Distal Femoral Surgical Protocol.pdf', 'file_path': '/Users/andrewyang/Desktop/research/AgenticRAG/orthoagent/reference_docs/003 GMRS Distal Femoral Surgical Protocol.pdf', 'file_type': 'app ...

# %%
from orthoagent.agents.agent import multimodal_agent

response = multimodal_agent.chat("Is there a press fit or cementless option? Give me the answer for 1.) depuy 2.) onko 3.)zimmer 4.) stryker")
print(response.response)
# Out:
# Added user message to memory: Is there a press fit or cementless option? Give me the answer for 1.) depuy 2.) onko 3.)zimmer 4.) stryker
# === Calling Function ===
# Calling function: query_engine with args: {"input": "press fit or cementless option for DePuy implants"}
# Got output: Cementless option
# ========================
#
# === Calling Function ===
# Calling function: query_engine with args: {"input": "press fit or cementless option for Onko implants"}
# Got output: Cementless option.
# ========================
#
# === Calling Function ===
# Calling function: query_engine with args: {"input": "press fit or cementless option for Zimmer implants"}
# Got output: The Zimmer implants offer a press fit option for implant assembly without augments and segments.
# ========================
#
# === Calling Function ===
# Calling function: query_engine with args: {"input": "press fit or cementless option for Stryker implants"}
# Got output: The Stryker implants offer press fit options.
# ========================
#
# Here are the options for press fit or cementless implants for each company:
#
# 1. **DePuy**: Cementless option.
# 2. **Onko**: Cementless option.
# 3. **Zimmer**: The Zimmer implants offer a press fit option for implant assembly without augments and segments.
# 4. **Stryker**: The Stryker implants offer press fit options.
