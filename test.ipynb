# %%
from orthoagent.agents.agent import multimodal_agent
multimodal_agent.chat("“How long is the distal femoral component?” Give me the answer for 1.) depuy 2.) onko 3.)zimmer 4.) stryker")
# Out:
# Loading files: 100%|██████████| 4/4 [00:03<00:00,  1.11file/s]
# /Users/andrewyang/anaconda3/lib/python3.11/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# Started parsing the file under job_id 1b94e650-664c-4de6-b294-fb2223c7fa4c
# Started parsing the file under job_id cae666de-23aa-4df2-9d61-add98e70cb23
# Started parsing the file under job_id e2fe9331-4208-49e3-a966-833ce752620a
# Started parsing the file under job_id 2cc4622f-5540-4910-bf93-8f6115615bf5
# Added user message to memory: “How long is the distal femoral component?” Give me the answer for 1.) depuy 2.) onko 3.)zimmer 4.) stryker
# === Calling Function ===
# Calling function: query_engine with args: {"input": "distal femoral component length site:depuy.com"}
# ...

# %%
response = multimodal_agent.chat("Fill in the blank. The Orthogenesis LPS stem extensions are available _____")

print(response.response)
# Out:
# Added user message to memory: Fill in the blank. The Orthogenesis LPS stem extensions are available _____
# === Calling Function ===
# Calling function: query_engine with args: {"input":"Orthogenesis LPS stem extensions availability"}
# Got output: The provided context does not explicitly mention the availability of stem extensions for the Orthogenesis Limb Preservation System (LPS). However, it does state that the distal femoral and tibial components, tibial stems, and non-porous coated femoral stems are intended for cemented use only. This implies that various stem components are available as part of the system, but specific details about stem extensions are not provided in the given information. For more detailed information, it would be advisable to consult the full labeling or visit the provided website [www.jnjgateway.com/orthogenesis](http://www.jnjgateway.com/orthogenesis).
# ...
#
# ...

# %%
from orthoagent.agents.agent import multimodal_agent

response = multimodal_agent.chat("Is there a press fit or cementless option? Give me the answer for 1.) depuy 2.) onko 3.)zimmer 4.) stryker")
print(response.response)
# Out:
# Added user message to memory: Is there a press fit or cementless option? Give me the answer for 1.) depuy 2.) onko 3.)zimmer 4.) stryker
# === Calling Function ===
# Calling function: query_engine with args: {"input": "press fit or cementless option for DePuy implants"}
# Got output: Cementless option
# ...
#
# === Calling Function ===
# Calling function: query_engine with args: {"input": "press fit or cementless option for Onko implants"}
# Got output: Cementless option.
# ...
#
# === Calling Function ===
# Calling function: query_engine with args: {"input": "press fit or cementless option for Zimmer implants"}
# Got output: The Zimmer implants offer a press fit option for implant assembly without augments and segments.
# ...
#
# === Calling Function ===
# Calling function: query_engine with args: {"input": "press fit or cementless option for Stryker implants"}
# Got output: The Stryker implants offer press fit options.
# ...
#
# Here are the options for press fit or cementless implants for each company:
# ...
